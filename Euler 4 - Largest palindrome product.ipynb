# %% [markdown]
# ## Largest palindrome product
#
# **Problem 4 **
#
# A palindromic number reads the same both ways. The largest palindrome made from the product of two 2-digit numbers is 9009 = 91 × 99.
#
# Find the largest palindrome made from the product of two 3-digit numbers.

# %%
def is_palindrome(n):
    number = str(n)
    l = len(number)
    for i in range(0, int(l/2)):
        if(number[i]!=number[l-i-1]):
            return False
            
    return True

# %%
is_palindrome(1012101)
# Out:
# True

# %%
def largest_palindrome(number):
    n=number*2-2
    for i in range(0,number-1):
        sum = n-i
        m=(sum)/2
        j=0
        while sum-(m-j)<number:
            num1 = sum-(m-j)
            num2 = m-j
            
            if(is_palindrome(num1*num2)):
                return(num1*num2)
            else:
                j+=1
                continue

# %%
largest_palindrome(1000)
# Out:
# 906609

# %%
n=1000
my_list = []
for i in range(90, n):
    for j in range(90,i+1):
        my_list.append((i,j,i+j,i*j))
#         print(i,j,i*j)
my_list.sort(key=lambda t: t[3], reverse=True)

# %%
my_list
# Out:
# [(999, 999, 1998, 998001),
#  (999, 998, 1997, 997002),
#  (998, 998, 1996, 996004),
#  (999, 997, 1996, 996003),
#  (998, 997, 1995, 995006),
#  (999, 996, 1995, 995004),
#  (997, 997, 1994, 994009),
#  (998, 996, 1994, 994008),
#  (999, 995, 1994, 994005),
#  (997, 996, 1993, 993012),
#  (998, 995, 1993, 993010),
#  (999, 994, 1993, 993006),
#  (996, 996, 1992, 992016),
#  (997, 995, 1992, 992015),
#  (998, 994, 1992, 992012),
#  (999, 993, 1992, 992007),
#  (996, 995, 1991, 991020),
#  (997, 994, 1991, 991018),
#  (998, 993, 1991, 991014),
#  (999, 992, 1991, 991008),
#  (995, 995, 1990, 990025),
#  (996, 994, 1990, 990024),
#  (997, 993, 1990, 990021),
#  (998, 992, 1990, 990016),
#  (999, 991, 1990, 990009),
#  (995, 994, 1989, 989030),
#  (996, 993, 1989, 989028),
#  (997, 992, 1989, 989024),
#  (998, 991, 1989, 989018),
#  (999, 990, 1989, 989010),
#  (994, 994, 1988, 988036),
#  (995, 993, 1988, 988035),
#  (996, 992, 1988, 988032),
#  (997, 991, 1988, 988027),
# ...
